# %%
import pandas as pd

# %%
spanishPlayers = pd.Series(
    ['Casillas', 'Ramos', 'Pique', 'Puyol', 'Capdevila', 'Xabi Alonso', 'Busquets', 'Xavi Hernandez', 'Pedrito',
     'Iniesta', 'Villa'], index=[1, 15, 3, 5, 11, 14, 16, 8, 18, 6, 7])
print "Spanish Football Players: \n%s" % spanishPlayers
# Out:
# Spanish Football Players:
# 1           Casillas
# 15             Ramos
# 3              Pique
# 5              Puyol
# 11         Capdevila
# 14       Xabi Alonso
# 16          Busquets
# 8     Xavi Hernandez
# 18           Pedrito
# 6            Iniesta
# 7              Villa
# dtype: object

# %%
abogados = pd.read_excel("C:\\Users\\Vic\\Downloads\\abogados.xls")

# %%
abogados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 49 columns):
# Número de de identificación:                                                138 non-null object
# Fecha de inscripción:                                                       138 non-null object
# Categoría                                                                   138 non-null object
# Subcategoría                                                                138 non-null object
# Nombre (de la organización)                                                 138 non-null object
# Personalidad jurídica:                                                      138 non-null object
# Sitio web:                                                                  126 non-null object
# País de la sede central                                                     138 non-null object
# Dirección de la sede central                                                138 non-null object
# ...

# %%
abogados.head()
# Out:
#   Número de de identificación: Fecha de inscripción:  \
# 0              730374427171-41            15/05/2017
# 1               15066281874-49            22/06/2009
# 2               14930521693-76            14/05/2009
# 3               13795213569-71            10/05/2010
# 4              608050616762-69            26/03/2015
#
#                                            Categoría         Subcategoría  \
# 0  I - Consultorías profesionales, bufetes de abo...  Bufetes de abogados
# 1  I - Consultorías profesionales, bufetes de abo...  Bufetes de abogados
# 2  I - Consultorías profesionales, bufetes de abo...  Bufetes de abogados
# 3  I - Consultorías profesionales, bufetes de abo...  Bufetes de abogados
# 4  I - Consultorías profesionales, bufetes de abo...  Bufetes de abogados
#
#                          Nombre (de la organización)  \
# 0                           Jalsovszky Ügyvédi Iroda
# 1  Intellectual Property Lawyers' Association (IPLA)
# ...

# %%
abogados.Clientes.value_counts()
# Out:
# ABB AB                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Bolton Alimentari SpA, Governo greco                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# ...

# %%
abogados.Cargo.value_counts()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-10-b9877e3003c7> in <module>()
# ----> 1 abogados.Cargo.value_counts()
#
# d:\code\first-python-notebook\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Cargo'

# %%
provee = pd.read_excel("C:\\Users\\Vic\\Downloads\\273 proveedores ayto 2016.xls")

# %%
provee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2716 entries, 0 to 2715
# Data columns (total 2 columns):
# Proveedores    2716 non-null object
# Unnamed: 1     2716 non-null object
# dtypes: object(2)
# memory usage: 21.3+ KB

# %%
provee.min()
# Out:
# Proveedores    1978 KOOPERATIBA SOCIEDAD COOPERATIVA
# Unnamed: 1                                 1.45519e-11
# dtype: object

# %%
provee17 = pd.read_excel("C:\\Users\\Vic\\Downloads\\289 proveedores ayto 2017.xls")

# %%
provee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2716 entries, 0 to 2715
# Data columns (total 2 columns):
# Proveedores    2716 non-null object
# Unnamed: 1     2716 non-null object
# dtypes: object(2)
# memory usage: 21.3+ KB

# %%
provee17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1023 entries, 0 to 1022
# Data columns (total 2 columns):
# Proveedores    1023 non-null object
# Unnamed: 1     1023 non-null object
# dtypes: object(2)
# memory usage: 8.0+ KB

# %%
provee15 = pd.read_excel("C:\\Users\\Vic\\Downloads\\194 proveedores ayto 2015.xls")

# %%
provee15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2534 entries, 0 to 2533
# Data columns (total 2 columns):
# Proveedores    2534 non-null object
# Unnamed: 1     2534 non-null object
# dtypes: object(2)
# memory usage: 19.8+ KB

# %%
pd.merge (provee, provee15, on="Proveedores")
# Out:
#                                             Proveedores Unnamed: 1_x  \
# 0                                                Nombre      Importe
# 1                                        DORNIER S.A.    8.65261e+06
# 2            FOMENTO DE CONSTRUCCIONES Y CONTRATAS SA    7.88179e+06
# 3         ESCUELAS INFANTILES MUNICIPALES DE PAMPLONA    6.30015e+06
# 4                               GERENCIA DE URBANISMO    5.70767e+06
# 5      ASOCIACION NAVARRA DE INFORMATICA MUNICIPAL SA    4.63493e+06
# 6                                           SEDENA SL    3.82295e+06
# 7                              ONDEMAND FACILITIES SL     3.3934e+06
# 8                      SERVISAR SERVICIOS SOCIALES SL    2.94975e+06
# 9                 EULEN SA ONDEMAND FACILITIES SL UTE    2.83672e+06
# 10                                           EULEN SA    2.42342e+06
# 11                     UTE CONSERVACION PAMPLONA 2015    2.24102e+06
# 12             MANCOMUNIDAD DE LA COMARCA DE PAMPLONA    2.17196e+06
# ...

# %%
merged = pd.merge (provee, provee15, on="Proveedores")

# %%
merged.head()
# Out:
#                                      Proveedores Unnamed: 1_x Unnamed: 1_y
# 0                                         Nombre      Importe      Importe
# 1                                 DORNIER S.A.    8.65261e+06  8.63948e+06
# 2     FOMENTO DE CONSTRUCCIONES Y CONTRATAS SA    7.88179e+06      7929761
# 3  ESCUELAS INFANTILES MUNICIPALES DE PAMPLONA    6.30015e+06  5.36155e+06
# 4                        GERENCIA DE URBANISMO    5.70767e+06  3.80844e+06

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1483 entries, 0 to 1482
# Data columns (total 3 columns):
# Proveedores     1483 non-null object
# Unnamed: 1_x    1483 non-null object
# Unnamed: 1_y    1483 non-null object
# dtypes: object(3)
# memory usage: 29.0+ KB
